# %%
# %load_ext autoreload
# %autoreload 2
from gematriakit import *
# %matplotlib inline


# Plotting Gematria Timeseries
plot_colormesh(np.array(all), sort=True)
plot_colormesh(np.array(torah))
plot_colormesh(np.array(neviim))
plot_colormesh(np.array(ketubim))
plot_colormesh(np.array(all))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Plotting Correlations
plot_correlations(np.array(torah))
plot_correlations(np.array(neviim))
plot_correlations(np.array(ketubim))
plot_correlations(np.array(all))

# %%
plot_all_gematrias(['Genesis'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-7337018cbb30> in <module>()
# ----> 1 plot_all_gematrias(['Genesis'])
#
# /Users/akivalipshitz/Developer/Computational_Tanach/src/gematriakit.py in plot_all_gematrias(booklist)
#      70     books = booklist if len(booklist)>0 else np.unique(np.array(tanach['book']))
#      71
# ---> 72     dims = dimensions(books.shape[0])
#      73     f, axes = plt.subplots(*dims, figsize=(20,20))
#      74     f.suptitle('Gematria Values for Nth Sentence Across all Books in Bible [old testament]')
#
# AttributeError: 'list' object has no attribute 'shape'
